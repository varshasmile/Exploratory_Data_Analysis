# %% [markdown]
# ## RED WINE QUALITY - Exploratory Data Analysis (EDA)

# %% [markdown]
# ## What is EDA?
# According to Wikipedia, exploratory data analysis (EDA) is an approach to analyze data sets to summarize their main characteristics, often with visual methods.
#
# It helps us to uncover the underlying structure of data and its dynamics through which we can maximize the insights. EDA is also critical to extract important variables and detect outliers and anomalies. EDA is considered one of the most critical parts to understand the data.
#
# Some of the common plots used for Exploratory Data Analysis:
#
# - Histograms
# - Scatter plots
# - Pair plots
# - Box plots
# - Violin plots
# - Distribution Plots

# %% [markdown]
# ## Introduction
# It consists of Exploratory Data Analysis (EDA), predictive models and evaluation of those models for predicting the quality of wine, given a list of wine characteristics.

# %% [markdown]
# ## ABOUT DATASET
#
# The Wine Quality dataset contains information about various physicochemical properties of wines. The entire dataset has a quality label associated with it. The label is in the range of 0 to 10. In the next section, we are going to download and load the dataset into Python and perform an initial analysis to disclose what is inside it.

# %% [markdown]
# ## Problem Specification
# The dataset specifies the quality of wine, given a list of attributes. These attributes are also known as feature set of a dataset. Along with these features, we have a label for each entry of the data, the quality of the wine which is basically a score between 0 and 10.
#
# Now, given those features and label, we have to predict the quality of wine for some unknown set of data (test data) where the quality is not given.

# %% [markdown]
# ## FEATURES DESCRIPTION
#
# - Fixed acidity: It indicates the amount of tartaric acid in wine and is measured in g/dm3
# - Volatile acidity: It indicates the amount of acetic acid in the wine. It is measured in g/dm3.
# - Citric acid: It indicates the amount of citric acid in the wine. It is also measured in g/dm3
# - Residual sugar: It indicates the amount of sugar left in the wine after the fermentation process is done. It is also measured in g/dm3
# - Free sulfur dioxide: It measures the amount of sulfur dioxide (SO2) in free form. It is also measured in g/dm3
# - Total sulfur dioxide: It measures the total amount of SO2 in the wine. This chemical works as an antioxidant and antimicrobial agent.
# - Density: It indicates the density of the wine and is measured in g/dm3.
# - pH: It indicates the pH value of the wine. The range of value is between 0 to 14.0, which indicates very high acidity, and 14 indicates basic acidity.
# - Sulphates: It indicates the amount of potassium sulphate in the wine. It is also measured in g/dm3.
# - Alcohol: It indicates the alcohol content in the wine.
# - Quality: It indicates the quality of the wine, which is ranged from 1 to 10. Here, the higher the value is, the better the wine.

# %% [markdown]
# ## Aim:
# In this project, I am going to analyse the red wine quality dataset, perform data cleaning and try to figure out on what factors the wine quality depends. I've downloaded this dataset from Kaggle, containg the wine composition information and the resulting alcohol in the wine and the quality of red wine. For this, I will use several methods form numpy, matplotlib and seaborn libraries.

# %% [markdown]
# ## The process:
# 1. Data Extraction
# - Downloading a publicly available dataset
# - Describing the dataset
#
# 2. Data Pre-processing
# - Cleaning/removing invalid values from rows
# - Cleaning up columns
# - Removing/filling missing data
# - Creating new columns
# - Modifying exsting columns
#
# 3. Data Visualization

# %% [markdown]
# ## Import libraries
# Setting up the development environment by importing required libraries and modules:
#
# 1. Numpy: It will provide the support for efficient numerical computation.
# 2. Pandas: It is convenient library that supports dataframes. Working with pandas will bring ease in many crucial data operations.
# 3. Matplotlib: It provides a MATLAB-like plotting framework.
# 4. Seaborn: It is a visualization library based on matplotlib which provides a high-level interface for drawing attractive statistical graphics.
# 5. Sklearn: It is python library for data mining, data analysis and machine learning.
# 6. %matplotlib - to enable the inline plotting
# 7. warnings - to manipulate warnings details
# 8. filterwarnings('ignore') is to ignore the warnings thrown by the modules (gives clean results)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Data upload
# Load the datasets, we can load the data with the csv files.
# Use Pandas to create DataFrames.

# %%
df = pd.read_csv('winequality-red.csv')

# %%
## Load the first 5 rows.
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
## Get the number of rows and columns of the DataFrame.
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# Observation : The shape of the data is (1599,12), which shows there are 1599 rows and 12 columns in the data.

# %%
## To know the columns of the data, we can do df.columns, it will give all the features name present in the data.
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
## The describe () function in Python summarizes statistics. This function returns the count, mean, standard deviation, minimum and maximum values, and the quantiles of the data.
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Observations:
#
# There is a large difference between the 75th% tile and max values of residual sugar, free sulfur dioxide & total sulfur dioxide.\
# The summary of Red Wine dataset looks perfect, there is no visible abnormality in data (invalid/negative values).\
# All the data seems to be in range (with different scales, which needs standardization).

# %%
#datatype information:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Observation: We can see that, all 12 columns are of numeric data types. Out of 12 variables, 11 are predictor variables and last one 'quality' is an response variable.

# %%
## Let's check if there is any missing value in the data.
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Observation: There is no missing data.\
# It seems that data has been collected neatly or prior cleaning has been performed before publishing the dataset.

# %%
## The below-shown function will print the number of unique values in each of the features.
for col in df.columns.values:
    print(f'Number of unique values of {col} : {df[col].nunique()}')
# Out:
# Number of unique values of fixed acidity : 96
# Number of unique values of volatile acidity : 143
# Number of unique values of citric acid : 80
# Number of unique values of residual sugar : 91
# Number of unique values of chlorides : 153
# Number of unique values of free sulfur dioxide : 60
# Number of unique values of total sulfur dioxide : 144
# Number of unique values of density : 436
# Number of unique values of pH : 89
# Number of unique values of sulphates : 96
# Number of unique values of alcohol : 65
# Number of unique values of quality : 6

# %% [markdown]
# Observations:
#
# - The feature that has a maximum unique value is density.
# - The feature that has a minimum unique value is quality.

# %%
## Let's check how many unique values does the target feature 'quality' has
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
## And how data is distributed among those values
df.quality.value_counts().sort_index()
# Out:
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
## check duplicates
df.duplicated().sum()
# Out:
# 240

# %%
## removing duplicates
df.drop_duplicates(inplace=True)

# %%
## We are trying to figure out the correlation of every other feature w.r.t the quality of the wine.
df.corr()['quality']
# Out:
# fixed acidity           0.119024
# volatile acidity       -0.395214
# citric acid             0.228057
# residual sugar          0.013640
# chlorides              -0.130988
# free sulfur dioxide    -0.050463
# total sulfur dioxide   -0.177855
# density                -0.184252
# pH                     -0.055245
# sulphates               0.248835
# alcohol                 0.480343
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# Let's create a new discrete, categorical response variable/feature ('rating') from existing 'quality' variable.\
# i.e. bad: 1-4\
#       average: 5-6\
#       good: 7-10

# %%
conditions = [
    (df['quality'] >= 7),
    (df['quality'] <= 4)
]
rating = ['good', 'bad']
df['rating'] = np.select(conditions, rating, default='average')
df.rating.value_counts()
# Out:
# average    1112
# good        184
# bad          63
# Name: rating, dtype: int64

# %%
df.groupby('rating').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# rating
# average       8.251169          0.538898     0.261286        2.484397
# bad           7.871429          0.724206     0.173651        2.684921
# good          8.820109          0.405870     0.372880        2.703804
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# rating
# average   0.089691            16.428058             49.424910  0.996834
# bad       0.095730            12.063492             34.444444  0.996689
# good      0.076049            13.972826             35.358696  0.995963
#
#                pH  sulphates    alcohol   quality
# rating
# average  3.309083   0.648094  10.259173  5.481115
# bad      3.384127   0.592222  10.215873  3.841270
# good     3.288587   0.745598  11.552808  7.092391

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Heatmap of correlation matrix
# We are trying to figure out the correlation of every other feature w.r.t the quality of the wine.
#
# A positive correlation means that as the value of the first parameter increases, so will the second one. For example, with a higher content of acid in the red wine, the wine has a higher density, since the acids themselves are denser than water.
#
# A negative correlation means that as the value of the first parameter increases, the value of the second parameter decreases. For example, with a higher acid content in red wine, the pH value will be lower, indicating an acidic environment.
#
# The closer the correlation value is to zero, the less the parameters affect each other.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,center=0,cmap='coolwarm')
plt.show()

# %% [markdown]
# Observation:
#
# - density has a strong positive correlation with residual sugar, whereas it has a strong negative correlation with alcohol.
# - pH & fixed acidity has negative correlation.
# - density & fixed acidity has positive correlation.
# - citric acid & fixed acidity has positive correlation.
# - citric acid & volatile acidity has negative correlation.
# - free sulphur dioxide & total sulphur dioxide has positive correlation.

# %%
## the distribution of the quality of the wine in the dataset

plt.hist(df.quality,bins=6,alpha=0.5,histtype='bar',ec='black')
plt.title('Distribution of the Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Observation: The above plot shows the distribution of the quality of the wine in the dataset, and represents that most of the wine is of average quality i.e. quality ranging from 5-7 .

# %%
## the barplot of quality vs ph

plt.figure(figsize=(8,5))
sns.barplot(x=df['quality'], y=df['pH'], palette="GnBu_d")
plt.show()

# %% [markdown]
# Observation: From the barplot of qulaity vs ph we can visualize that there is a slight decrease in pH with the increase in quality of the wine.

# %%
## Boxplot of Quality and pH

sns.boxplot(x='quality',y='pH',data=df,palette='GnBu_d')
plt.title("Boxplot of Quality and pH")
plt.show()

# %%
## Boxplot of Quality and Alcohol

ax = sns.boxplot(x='quality',y='alcohol',data=df,palette='GnBu_d')
plt.title("Boxplot of Quality and Alcohol")
plt.show()

# %% [markdown]
# Observation: The above plot shows the increase in the quality of wine with the increase in alcohol. \
# The quality of the wine is directly related to the amount of alcohol in the wine. \
# More the alcohol in the wine better will be the quality.

# %%
## Boxplot of Quality and residual sugar

sns.boxplot(x="quality",y="residual sugar",data=df,palette="GnBu_d")
plt.title("Boxplot of Quality and residual sugar")
plt.show()

# %% [markdown]
# Observation: There is not much effect of the residual sugar on the quality of the wine.

# %%
## Boxplot of Quality and Density

sns.boxplot(x="quality",y="density",data=df,palette="GnBu_d")
plt.title("Boxplot of Quality and Density")
plt.show()

# %% [markdown]
# Observation: Lower the density of wine better will be the quality of the wine. From the above boxplot we acn visualize that the quality of wine increases with decrease in density.

# %%
## Boxplot of Quality and Sulphates

sns.boxplot(x="quality",y="sulphates",data=df,palette="GnBu_d")
plt.title("Boxplot of Quality and Sulphates")
plt.show()

# %% [markdown]
# Observation: The above plot represents that the quality of alcohol increases with the increase in the amount of sulphates in the wine.

# %%
## Boxplot of Quality and Chlorides

sns.boxplot(x="quality",y="chlorides",data=df,palette="GnBu_d")
plt.title("Boxplot of Quality and Chlorides")
plt.show()

# %% [markdown]
# Observation: From the above plot we can see that there is not even a slight change in the quality of wine for a particular amount of chlorides mixed in them.

# %% [markdown]
# Effect of acidity on the quality of wine
#
# - Citric Acid
# - Volatile Acidity
# - Fixed Acidity

# %%
## Boxplot of Quality and Citric Acid

sns.boxplot(x="quality",y="citric acid",data=df,palette="coolwarm")
plt.title("Boxplot of Quality and Citric Acid")
plt.show()

# %% [markdown]
# Observation: The quality of the wine increses with increase in the amount of citric acid in the wine.

# %%
## Boxplot of Quality and Volatile Acidity

sns.boxplot(x="quality",y="volatile acidity",data=df,palette="coolwarm")
plt.title("Boxplot of Quality and Volatile Acidity")
plt.show()

# %% [markdown]
# Observation: From the above boxplot we can see that the quality of wine increases with the decrease in the amount of volatile acids.

# %%
## Boxplot of Quality and Fixed Acidity
 
sns.boxplot(x="quality",y="fixed acidity",data=df,palette="coolwarm")
plt.title("Boxplot of Quality and Fixed Acidity")
plt.show()

# %% [markdown]
# Observation: There is not much effect of fixed acidity on the quality of the wine.

# %% [markdown]
# A box-and-whisker plot displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum.
#
# In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.

# %%
plt.figure(figsize=(10, 15))
for i, col in enumerate(list(df.columns.values)):
    plt.subplot(4,3, i+1)
    df.boxplot(col)
    plt.grid()
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 plt.figure(figsize=(10, 15))
#       2 for i, col in enumerate(list(df.columns.values)):
# ----> 3     plt.subplot(4,3, i+1)
#       4     df.boxplot(col)
#       5     plt.grid()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:1264, in subplot(*args, **kwargs)
#    1261 fig = gcf()
#    1263 # First, search for an existing subplot with a matching spec.
# -> 1264 key = SubplotSpec._from_subplot_args(fig, args)
#    1266 for ax in fig.axes:
#    1267     # if we found an Axes at the position sort out if we can re-use it
#    1268     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1269         # if the user passed no kwargs, re-use
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/gridspec.py:612, in SubplotSpec._from_subplot_args(figure, args)
# ...

# %% [markdown]
# Observations:
#
# Outliers are the points outside the 1.5×IQR or more above the third quartile or 1.5×IQR or more below the first quartile.
#
# Except for alcohol, all other features have outliers.

# %%
## seaborn.distplot- This function plots the estimated PDF over the data
plt.figure(figsize=(10, 6))
for i, col in enumerate(list(df.columns.values)):
    plt.subplot(4,3, i+1)
    sns.distplot(df[col], color='r', kde=True, label='data')
    plt.grid()
    plt.legend(loc='upper right')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 plt.figure(figsize=(10, 6))
#       3 for i, col in enumerate(list(df.columns.values)):
# ----> 4     plt.subplot(4,3, i+1)
#       5     sns.distplot(df[col], color='r', kde=True, label='data')
#       6     plt.grid()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:1264, in subplot(*args, **kwargs)
#    1261 fig = gcf()
#    1263 # First, search for an existing subplot with a matching spec.
# -> 1264 key = SubplotSpec._from_subplot_args(fig, args)
#    1266 for ax in fig.axes:
#    1267     # if we found an Axes at the position sort out if we can re-use it
#    1268     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1269         # if the user passed no kwargs, re-use
#
# ...

# %% [markdown]
# Observations:
#
# wine quality is approximately normally distributed\
# the pH is normally distributed, with few outliers\
# fixed acidity have some outliers and peaks between 6 and 7\
# volatile acidity has quite a few outliers with high values, also slightly skewed to the right\
# most of the wines have citric acid within the range of 0.25-0.30 with few other spikes at 0.01 and 0.48\
# density has almost normal distribution\
# there are many outliers with high residual sugar and the distribution is skewed right\
# chloride distribution is skewed right with outliers.\
# distribution of free sulfur dioxide and total sulfur dioxide is skewed right

# %%
## #lets see whether our data has outliers or not:
## create box plots
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    sns.boxplot(y=col, data=df, color='b', ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 8
#       5 ax = ax.flatten()
#       7 for col, value in df.items():
# ----> 8     sns.boxplot(y=col, data=df, color='b', ax=ax[index])
#       9     index += 1
#      10 plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %% [markdown]
# Observation:
#
# We observe outliers from a few attributes.
#
# Eliminating these outliers will improve the accuracy of the model.
#
# Since it won't affect the outcome of the project, we will ignore this outlier.

# %%
## Alcohol versus pH
sns.jointplot(x='alcohol',y='pH',data=df, kind='reg')

# %% [raw]
# Observations:
#
# This Figure shows that alcohol is weakly positively related to the pH values. Moreover, the regression line is depicted in the figure, illustrating the correlation between them.

# %% [markdown]
# Some More Observations About the dataset:
# 1. no relation is found between fixed_acidity and alcohol.
# 2. fixed acidity seems to be proportional to citric acid amount, it may be because fixed acidity will be mainly due to citric acid.
# 3. pH is mainly due to fixed acidity of citric acid.
# 4. free sulfur dioxide increases linearly with total sulfur dioxide.
# 5. as density of wine increases, the alcohol quantity decreases. Also, there are very few samples of red wine, whose density is greater than one.

# %% [markdown]
# ## -- Some Questions --

# %% [markdown]
# Q1. What is the percentage of fixed sufur dioxide in red wine? Give answer in terms of average and range.

# %%
free_sulfur_dioxide_percent = (df['free sulfur dioxide'])/df['total sulfur dioxide']
free_sulfur_dioxide_percent.mean()
# Out:
# 0.38148752056436097

# %%
fixed_sulfur_dioxide = (df['total sulfur dioxide'] - df['free sulfur dioxide'])/df['total sulfur dioxide']
fixed_sulfur_dioxide.mean()
# Out:
# 0.618512479435639

# %%
sns.histplot(fixed_sulfur_dioxide)
# Out:
# <AxesSubplot: ylabel='Count'>

# %% [markdown]
# Q2. what is the quantity of alcohol in maximum red wines?

# %%
plt.hist(df.alcohol,bins =np.arange(8,15,1))
# Out:
# (array([  6., 570., 379., 258., 119.,  26.]),
#  array([ 8.,  9., 10., 11., 12., 13., 14.]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# Majority of red wines have alcohol quantity between 9-10.

# %%
df[(df.alcohol)>13].quality.describe()
# Out:
# count    22.000000
# mean      6.545455
# std       1.010765
# min       4.000000
# 25%       6.000000
# 50%       6.500000
# 75%       7.000000
# max       8.000000
# Name: quality, dtype: float64

# %% [markdown]
# Q3. How much chloride is present in best quality red wines?

# %%
df[df.quality==8].chlorides.describe()
# Out:
# count    17.000000
# mean      0.068353
# std       0.012031
# min       0.044000
# 25%       0.061000
# 50%       0.071000
# 75%       0.076000
# max       0.086000
# Name: chlorides, dtype: float64

# %% [markdown]
# chlorides are in the range 0.044 to 0.086.\
# It also indicates that the best quality wine has lower amount of chlorides.

# %% [markdown]
# Q4. If red wine quality 7 and above is considered good, what is the percentage of good quality wines produced?

# %%
df[df.quality>6].count()/df.count()
# Out:
# fixed acidity           0.135394
# volatile acidity        0.135394
# citric acid             0.135394
# residual sugar          0.135394
# chlorides               0.135394
# free sulfur dioxide     0.135394
# total sulfur dioxide    0.135394
# density                 0.135394
# pH                      0.135394
# sulphates               0.135394
# alcohol                 0.135394
# quality                 0.135394
# rating                  0.135394
# dtype: float64

# %% [markdown]
# Only 13.57 % of red wines produced are of good quality.

# %% [markdown]
# ## Inferences and Conclusion
#
# After analysing the dataset, no column has the strong correlation with output parameters, however some show slight relations.
#
# Fixed acidity is due to citric acid.\
# pH is influenced by fixed acidity.\
# Density of wine decreases with increase in the alcohol quantity.\
# On an average, fixed sulfur dioxie is 61.76% of the total sulfur dioxide in the red wine, though individual % varies.\
# Majority of red wines have alcohol quantity between 9-10.\
# chlorides are in the range 0.044 to 0.086. It also indicates that the best quality wine has lower amount of chlorides.\
# Only 13.57 % of red wines produced are of good quality.

# %% [markdown]
# The residual sugar feature in the Wine Quality dataset exhibits non-normality, as confirmed by the EDA analysis. The histogram and Q-Q plot of this feature show a non-normal distribution with a positive skew. Other features, such as fixed acidity, pH, and alcohol, exhibit normal or nearly normal distributions.
#
# According to the feature importance ranking analysis, the alcohol feature is the most important feature for predicting wine quality in the Wine Quality dataset. This indicates that wines with higher alcohol content tend to have higher quality ratings. Other features, such as volatile acidity, sulphates, and citric acid, also play a role in determining wine quality but are less important than alcohol.
#
# To improve normality in non-normal features, various transformation methods can be applied, including logarithmic transformation, square root transformation, and exponential transformation. All of these transformations can help to normalize skewed data by reducing the influence of outliers and improving the distribution's symmetry.
